# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank261193/Python/blob/main/18_july.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name="hello world"
