# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank261193/Python/blob/main/Mayank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Practice 1**

# %%
print("Hello,applied AI Lab") #First cell in collab
# Out:
# Hello,applied AI Lab

# %%
Name="Mayank Goyel"   #String stored
Age=31                #Variable stored
Marks=88              #Variable stored
print("Name:\t",Name) #Using tab spaces
print("Age:\t",Age)
print("Marks:\t",Marks)
# Out:
# Name:	 Mayank Goyel
# Age:	 31
# Marks:	 88

# %%
Name="Mayank Goyel"
Age=31
Marks=88
print(Name,Age,Marks) #Just print the data stored
# Out:
# Mayank Goyel 31 88

# %%
Age=31
Temp=36.6
Name="Mayank goyel"
Passed=True
print(type(Age)) #Tell the type of data stored
print(type(Temp))
print(type(Name))
print(type(Passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
Age=31
Price=99.5
print(float(2))    #Represent that number in decimal form
print(int(3.99))   #Give the greatest integer value
print(round(3.99)) #Round off the given number
# Out:
# 2.0
# 3
# 4

# %%
S="Data Science"
print(S[0])   #D
print(S[0:4]) #Data
print(S[-1])  #e
# Out:
# D
# Data
# e

# %%
print(len(S)) #Number of character including spaces
print(S.upper()) #Print upper case
print(S.lower()) #Print lower case
print(S.replace("Data","Applied"))
# Out:
# 12
# DATA SCIENCE
# data science
# Applied Science

# %%
Age= 31
Is_adult = Age>=18
print(Is_adult)
print(type(Is_adult))
# Out:
# True
# <class 'bool'>

# %%
print("10"+"10") #concatination
print(10+10)     #Addition
# Out:
# 1010
# 20

# %%
a=17
b=5
print(a+b)  #Addition of two numbers
print(a-b)  #Subtraction of two numbers
print(a*b)  #Multiplication of two numbers
print(a/b)  #Division of two numbers
print(a//b) #Quotient
print(a%b)  #Remainder
print(a**b) #Exponential : a raised to the power b
# Out:
# 22
# 12
# 85
# 3.4
# 3
# 2
# 1419857

# %%
Marks=90 #Assign
print(Marks==90) #Equal to
print(Marks!=90) #Not equal to
print(Marks>90)  #Greater than
print(Marks>=90) #Greater than or equal to
print(Marks<90)  #Less than
print(Marks<=90) #Less than equal to
# Out:
# True
# False
# False
# True
# False
# True

# %%
print(True and False) #And
print(True or False) #OR
print(not True)
# Out:
# False
# True
# False

# %%
Age = 31
print(Age >=30)
# Out:
# True

# %%
First="Mayank"                    #Assign
City="Ghaziabad"                  #Assign
print(First+" from "+ City)       #concatenation
print(F"{First} from {City}")     #f-string
messy=" Mayank goyel "            #Assign
print(messy.strip())              #dot strip method to remove any white spaces
print(messy.strip().title())      #dot title for capitalisation of first letter
print("a,b,c".split(","))         #dot split method divides into list of subt=strings
# Out:
# Mayank from Ghaziabad
# Mayank from Ghaziabad
# Mayank goyel
# Mayank Goyel
# ['a', 'b', 'c']

# %%
# Mistake 1 >>> = vs ==
score =90 #First assign the value
score ==90 #Bollean
# Out:
# True

# %%
# Mistake 2 >>> mixing text and numbers
# print("5"+5) >> Giv error because one is string and other is integer
print(int("5")+5) #convert string to integer
# Out:
# 10

# %%
# Mistake 3 >>> Forgetting quotes
# print(hello) >>> character should be in quotes single of double
print ('hello')
# Out:
# hello

# %%
# Mistake 4 : case sensitive
Name="Mayank"
#print(name) will give error because n should be capital
print(Name)
# Out:
# Mayank

# %%
print(type('88')) #string in quotes
print(17//5) #quotient
print(True and False) #And operator>>T and F should be capital
# Out:
# <class 'str'>
# 3
# False

# %%
F=90 #Temperature in fahrenheit
C=(F-32)*5/9 #celcius to fahrenheit
print(f"{F}F is {round(C,1)}C") #Roundoff C to one decimal place
# Out:
# 90F is 32.2C

# %%
#Split a bill
Bill=2999
Number_of_People=4
Tip=0.1*Bill
Total=Bill+Tip
Per_person_Bill= Total/Number_of_People
print(f"Total bill with tip:\t{round(Total,2)}")
print(f"Each pays:\t\t{int(Per_person_Bill)}")
print(f"Each pays:\t\t{round(Per_person_Bill,4)}")
# Out:
# Total bill with tip:	3298.9
# Each pays:		824
# Each pays:		824.725

# %%
#Build a username
Full_Name="Mayank goyel"
Birth_Year=1994
Clean=Full_Name.strip().title()
Parts=Clean.split()
Initials=Parts[0][0]+"."+Parts[1][0]+"." #calling of particular values
Username=Parts[0][0].lower()+str(Birth_Year)[-2:]
print(F"Initials:\t{Initials}")
print(f"Username:\t{Username}")
# Out:
# Initials:	M.G.
# Username:	m94

# %% [markdown]
# # Practice 2- Data types and operators
